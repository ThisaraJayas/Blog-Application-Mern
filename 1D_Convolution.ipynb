# %% [markdown]
# <a href="https://colab.research.google.com/github/ThisaraJayas/Blog-Application-Mern/blob/main/1D_Convolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#     Open Google colab.
#
# https://colab.research.google.com/
#
#
#     Upload the 1D_Convolution.ipynb notebook to colab. Run all cells (Runtime->Run all). Can you explain what you observe as the output? Can you explain the reason for getting that output? Based on the output, can you explain how it’s possible to detect the edges of an image using the Convolution operator?
#
#
#     Now change the input array to 1, 1, 1, 0.5, 0.5, 1, 1, 0.5, 0.5, 0.5.
#
#
# Run the notebook again using the ‘Run all’ menu item. What can you say about the new output?

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
signal = np.array([1, 1, 0.5, 0.5, 1, 1, 1, 0.5, 0.5, 0.5])

# %%
plt.stem(signal)
plt.show()

# %%
filter = np.array([-1, 1])

# %%
result = np.convolve(signal, filter, 'valid')

# %%
plt.stem(result)
plt.show()
